# %% [markdown]
# # Import libraries

# %%
from typing import Tuple, Dict, Any
from collections import defaultdict

from tqdm import tqdm

from AI.src.data.model import VideoMetadata

from AI.src.data.model import VideoMetadata
from AI.src.data.dataset import datasets
from AI.src.utils.visualize_dataset import prompt_dataset_statistics, plot_dataset_statistics

# %% [markdown]
# # UCF crime

# %%
ds = datasets["VideoFolderDataset"](r"D:\UCF\UCF-visua", "v3")

stats = {
    "total_samples": 0,
    "class_count": defaultdict(int),
    "fps_count": defaultdict(int),
    "resolution": defaultdict(int),
    "duration": defaultdict(int)
}

for i, (stream_info, target) in tqdm(enumerate(ds), total=len(ds), colour="red"):
    class_name = ds.classes[target]
    fps: None | int = getattr(stream_info, "frame_rate", None)
    num_frames: None | int = getattr(stream_info, "num_frames", None)
    resolution: Tuple[int, int] = (getattr(stream_info, "width", 0), getattr(stream_info, "height", 0))

    if not (fps is None and num_frames is None) and fps > 0:
        length: int = num_frames // fps
    else:
        length: None = None

    metadata: Dict[str, Any] = VideoMetadata(fps, length, resolution).to_dict()
    
    # Update stats
    stats["total_samples"] += 1
    stats["class_count"][class_name] += 1
    
    if fps is not None:
        stats["fps_count"][fps] += 1
    
    if resolution != (0, 0):
        stats["resolution"][resolution] += 1
    
    if length is not None:
        stats["duration"][length] += 1

# from pprint import pprint as pp
# pp(stats)
print(prompt_dataset_statistics(stats))
plot_dataset_statistics(ds, fpath="../fig/Dataset/UCF/")
# Out:
# 100%|██████████| 1900/1900 [00:07<00:00, 256.59it/s]
# ----------------------------------------  DATASET STATISTICS  ----------------------------------------
# DATASET STATISTICS
# Total number of videos: 1900
# Number of videos per class:
#   - Abuse: 50 videos
#   - Arrest: 50 videos
#   - Arson: 50 videos
#   - Assault: 50 videos
#   - Burglary: 100 videos
#   - Explosion: 50 videos
#   - Fighting: 50 videos
#   - Normal: 950 videos
#   - RoadAccidents: 150 videos
#   - Robbery: 150 videos
#   - Shooting: 50 videos
#   - Shoplifting: 50 videos
#   - Stealing: 100 videos
#   - Vandalism: 50 videos
# Average FPS: 28.32
# Average resolution: (320, 240)
# Shortest duration: 3.00 seconds
# Longest duration: 32550.00 seconds
# Average duration: 724.80 seconds
# ------------------------------------------------------------------------------------------------------

# %% [markdown]
# # UBI_FIGHTS

# %%
ds = datasets["VideoFolderDataset"](r"D:\UBI\UBI_FIGHTS", "v3")

stats = {
    "total_samples": 0,
    "class_count": defaultdict(int),
    "fps_count": defaultdict(int),
    "resolution": defaultdict(int),
    "duration": defaultdict(int)
}

for i, (stream_info, target) in tqdm(enumerate(ds), total=len(ds), colour="red"):
    class_name = ds.classes[target]
    fps: None | int = getattr(stream_info, "frame_rate", None)
    num_frames: None | int = getattr(stream_info, "num_frames", None)
    resolution: Tuple[int, int] = (getattr(stream_info, "width", 0), getattr(stream_info, "height", 0))

    if not (fps is None and num_frames is None) and fps > 0:
        length: int = num_frames // fps
    else:
        length: None = None

    metadata: Dict[str, Any] = VideoMetadata(fps, length, resolution).to_dict()
    
    # Update stats
    stats["total_samples"] += 1
    stats["class_count"][class_name] += 1
    
    if fps is not None:
        stats["fps_count"][fps] += 1
    
    if resolution != (0, 0):
        stats["resolution"][resolution] += 1
    
    if length is not None:
        stats["duration"][length] += 1

# from pprint import pprint as pp
# pp(stats)

print(prompt_dataset_statistics(stats))
plot_dataset_statistics(ds, fpath="../fig/Dataset/UBI-Fight/")
# Out:
# 100%|██████████| 1000/1000 [00:06<00:00, 154.02it/s]
# ----------------------------------------  DATASET STATISTICS  ----------------------------------------
# DATASET STATISTICS
# Total number of videos: 1000
# Number of videos per class:
#   - Fight: 216 videos
#   - Normal: 784 videos
# Average FPS: 30.00
# Average resolution: (640, 360)
# Shortest duration: 16.00 seconds
# Longest duration: 6416.00 seconds
# Average duration: 1465.14 seconds
# ------------------------------------------------------------------------------------------------------

# %% [markdown]
# # IITB

# %%
ds = datasets["VideoFolderDataset"](r"D:\IITB\IITB_visua", "v3")

stats = {
    "total_samples": 0,
    "class_count": defaultdict(int),
    "fps_count": defaultdict(int),
    "resolution": defaultdict(int),
    "duration": defaultdict(int)
}

for i, (stream_info, target) in tqdm(enumerate(ds), total=len(ds), colour="red"):
    class_name = ds.classes[target]
    fps: None | int = getattr(stream_info, "frame_rate", None)
    num_frames: None | int = getattr(stream_info, "num_frames", None)
    resolution: Tuple[int, int] = (getattr(stream_info, "width", 0), getattr(stream_info, "height", 0))

    if not (fps is None and num_frames is None) and fps > 0:
        length: int = num_frames // fps
    else:
        length: None = None

    metadata: Dict[str, Any] = VideoMetadata(fps, length, resolution).to_dict()
    
    # Update stats
    stats["total_samples"] += 1
    stats["class_count"][class_name] += 1
    
    if fps is not None:
        stats["fps_count"][fps] += 1
    
    if resolution != (0, 0):
        stats["resolution"][resolution] += 1
    
    if length is not None:
        stats["duration"][length] += 1

# from pprint import pprint as pp
# pp(stats)
print(prompt_dataset_statistics(stats))
plot_dataset_statistics(ds, fpath="../fig/Dataset/IITB/")
# Out:
# 100%|██████████| 354/354 [00:00<00:00, 373.68it/s]
# ----------------------------------------  DATASET STATISTICS  ----------------------------------------
# DATASET STATISTICS
# Total number of videos: 354
# Number of videos per class:
#   - BagExchange: 12 videos
#   - CarryObject: 58 videos
#   - Chasing: 18 videos
#   - Cycling: 11 videos
#   - Fighting: 9 videos
#   - Hiding: 10 videos
#   - Loitering: 38 videos
#   - Normal: 161 videos
#   - PlayingWithBall: 14 videos
#   - Protest: 11 videos
#   - SuddenRunning: 12 videos
# Average FPS: 25.00
# Average resolution: (1920, 1080)
# Shortest duration: 3.00 seconds
# Longest duration: 511.00 seconds
# Average duration: 85.66 seconds
# ------------------------------------------------------------------------------------------------------
